# %% [markdown]
# # Part1

# %% [markdown]
# # Task1

# %%
import sqlite3

conn = sqlite3.connect("company.db")
cursor = conn.cursor()

cursor.execute("""
CREATE TABLE IF NOT EXISTS employees (
    id INTEGER PRIMARY KEY,
    name TEXT,
    department TEXT,
    salary INTEGER
)
""")

cursor.execute("""
CREATE TABLE IF NOT EXISTS sales (
    sale_id INTEGER PRIMARY KEY,
    employee_id INTEGER,
    amount INTEGER,
    sale_date TEXT
)
""")

conn.commit()
conn.close()

print("Database & tables created successfully")
# Out:
# Database & tables created successfully

# %% [markdown]
# # Task2

# %%
import sqlite3

conn = sqlite3.connect("company.db")
cursor = conn.cursor()

employees = [
    (1,"Amit","IT",80000),(2,"Riya","HR",60000),(3,"John","Sales",75000),
    (4,"Sara","IT",90000),(5,"Kunal","Finance",85000),
    (6,"Anita","Sales",70000),(7,"Raj","HR",65000),
    (8,"Meena","IT",72000),(9,"Tom","Sales",78000),(10,"Neha","Finance",82000)
]

sales = [
    (1,3,5000,"2024-01-01"),(2,6,7000,"2024-01-02"),
    (3,9,8000,"2024-01-03"),(4,3,4000,"2024-01-04"),
    (5,6,6000,"2024-01-05"),(6,9,3000,"2024-01-06"),
    (7,3,9000,"2024-01-07"),(8,6,2000,"2024-01-08"),
    (9,9,1000,"2024-01-09"),(10,3,12000,"2024-01-10")
]

cursor.executemany("INSERT OR IGNORE INTO employees VALUES (?,?,?,?)", employees)
cursor.executemany("INSERT OR IGNORE INTO sales VALUES (?,?,?,?)", sales)

conn.commit()

print(cursor.execute("SELECT COUNT(*) FROM employees").fetchone())
print(cursor.execute("SELECT COUNT(*) FROM sales").fetchone())

conn.close()
# Out:
# (10,)
# (10,)

# %% [markdown]
# # Part2

# %% [markdown]
# # Task3

# %%
from sqlalchemy import create_engine, inspect

engine = create_engine("sqlite:///company.db")
inspector = inspect(engine)

print("Tables:", inspector.get_table_names())
# Out:
# Tables: ['employees', 'sales']

# %% [markdown]
# # Task4

# %%
from langchain_community.utilities import SQLDatabase

db = SQLDatabase.from_uri("sqlite:///company.db")

print("Available tables:", db.get_usable_table_names())
print("\nSchema Info:\n")
print(db.get_table_info())
# Out:
# Available tables: ['employees', 'sales']
#
# Schema Info:
#
#
# CREATE TABLE employees (
# 	id INTEGER,
# 	name TEXT,
# 	department TEXT,
# 	salary INTEGER,
# 	PRIMARY KEY (id)
# )
#
# /*
# 3 rows from employees table:
# id	name	department	salary
# 1	Amit	IT	80000
# 2	Riya	HR	60000
# 3	John	Sales	75000
# */
#
#
# CREATE TABLE sales (
# 	sale_id INTEGER,
# 	employee_id INTEGER,
# 	amount INTEGER,
# 	sale_date TEXT,
# 	PRIMARY KEY (sale_id)
# )
#
# /*
# 3 rows from sales table:
# sale_id	employee_id	amount	sale_date
# 1	3	5000	2024-01-01
# 2	6	7000	2024-01-02
# 3	9	8000	2024-01-03
# */

# %% [markdown]
# # Part3

# %%
conda install -c conda-forge pymysql
# Out:
# Channels:
#  - conda-forge
#  - defaults
# Platform: win-64
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: c:\conda\envs\venv
#
#   added / updated specs:
#     - pymysql
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2026.1.4   |       h4c7d964_0         144 KB  conda-forge
#     openssl-3.6.1              |       hf411b9b_1         8.9 MB  conda-forge
#     pymysql-1.1.2              |     pyhcf101f3_0          45 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         9.1 MB
#
# The following NEW packages will be INSTALLED:
#
#   pymysql            conda-forge/noarch::pymysql-1.1.2-pyhcf101f3_0
#
# The following packages will be UPDATED:
#
# ...

# %%
from sqlalchemy import create_engine, text

# Update with your MySQL credentials
MYSQL_URI = "mysql+pymysql://root:1111@localhost:3306/company_mysql"

engine = create_engine(MYSQL_URI)

with engine.connect() as conn:
    conn.execute(text("""
    CREATE TABLE IF NOT EXISTS employees (
        id INT PRIMARY KEY,
        name VARCHAR(100),
        department VARCHAR(50),
        salary INT
    )
    """))

    conn.execute(text("""
    CREATE TABLE IF NOT EXISTS sales (
        sale_id INT PRIMARY KEY,
        employee_id INT,
        amount INT,
        sale_date DATE
    )
    """))

print("MySQL tables created successfully")
# Out:
# MySQL tables created successfully

# %%
from sqlalchemy import text

with engine.connect() as conn:
    conn.execute(text("""
        INSERT IGNORE INTO employees VALUES
        (1,'Amit','IT',80000),(2,'Riya','HR',60000),
        (3,'John','Sales',75000),(4,'Sara','IT',90000),
        (5,'Kunal','Finance',85000)
    """))

    conn.execute(text("""
        INSERT IGNORE INTO sales VALUES
        (1,3,5000,'2024-01-01'),
        (2,3,7000,'2024-01-02'),
        (3,3,9000,'2024-01-03')
    """))

print("MySQL sample data inserted")
# Out:
# MySQL sample data inserted

# %%
from langchain_community.utilities import SQLDatabase

mysql_db = SQLDatabase.from_uri(
    "mysql+pymysql://root:1111@localhost:3306/company_mysql"
)

print("MySQL Tables:", mysql_db.get_usable_table_names())
print("\nMySQL Schema Info:\n")
print(mysql_db.get_table_info())
# Out:
# MySQL Tables: ['employees', 'sales']
#
# MySQL Schema Info:
#
#
# CREATE TABLE employees (
# 	id INTEGER NOT NULL,
# 	name VARCHAR(100),
# 	department VARCHAR(50),
# 	salary INTEGER,
# 	PRIMARY KEY (id)
# )COLLATE utf8mb4_0900_ai_ci ENGINE=InnoDB DEFAULT CHARSET=utf8mb4
#
# /*
# 3 rows from employees table:
# id	name	department	salary
# 1	Amit	IT	80000
# 2	Riya	HR	60000
# 3	John	Sales	75000
# */
#
#
# CREATE TABLE sales (
# 	sale_id INTEGER NOT NULL,
# 	employee_id INTEGER,
# 	amount INTEGER,
# 	sale_date DATE,
# 	PRIMARY KEY (sale_id)
# )COLLATE utf8mb4_0900_ai_ci ENGINE=InnoDB DEFAULT CHARSET=utf8mb4
#
# /*
# 3 rows from sales table:
# sale_id	employee_id	amount	sale_date
# 1	3	5000	2024-01-01
# 2	3	7000	2024-01-02
# 3	3	9000	2024-01-03
# */

# %%
print("SQLite Tables:", db.get_usable_table_names())
print("MySQL Tables:", mysql_db.get_usable_table_names())
# Out:
# SQLite Tables: ['employees', 'sales']
# MySQL Tables: ['employees', 'sales']

# %% [markdown]
# # Part4

# %% [markdown]
# # Task5

# %%
# MySQL example (won't execute unless MySQL is running)
from sqlalchemy import create_engine

mysql_engine = create_engine(
    "mysql+pymysql://username:password@localhost:3306/company_db"
)

print("MySQL engine created (connection test skipped)")
# Out:
# MySQL engine created (connection test skipped)

# %% [markdown]
# # Task6

# %%
from langchain_groq import ChatGroq
from langchain_community.agent_toolkits.sql.toolkit import SQLDatabaseToolkit
from dotenv import load_dotenv
load_dotenv()
llm = ChatGroq(
    model_name="llama-3.1-8b-instant"
)

toolkit = SQLDatabaseToolkit(db=db, llm=llm)

tools = toolkit.get_tools()

print("SQL Toolkit Tools:")
for t in tools:
    print("-", t.name)
# Out:
# SQL Toolkit Tools:
# - sql_db_query
# - sql_db_schema
# - sql_db_list_tables
# - sql_db_query_checker

# %% [markdown]
# # Task7

# %%
from langchain_core.messages import HumanMessage, ToolMessage

questions = [
    "How many employees are there in each department?",
    "Who has the highest salary?",
    "What is the total sales amount?",
    "What is the average salary per department?"
]

for q in questions:
    messages = [HumanMessage(content=q)]
    response = llm.bind_tools(tools).invoke(messages)

    tool_msgs = []
    for call in response.tool_calls:
        tool = next(t for t in tools if t.name == call["name"])
        result = tool.invoke(call["args"])
        tool_msgs.append(ToolMessage(tool_call_id=call["id"], content=str(result)))

    final = llm.bind_tools(tools).invoke(messages + [response] + tool_msgs)
    print("\nQ:", q)
    print("A:", final.content)
# Out:
# Q: How many employees are there in each department?
# A: This output means that there are 2 employees in the Finance department, 2 employees in the HR department, 3 employees in the IT department, and 3 employees in the Sales department.
#
# If you want to see all the details of the employees in each department, you might want to use a query like this:
#
#
#
# Q: Who has the highest salary?
# A: This means that Sara is the highest earner in the company and her salary is $90,000.
#
# Q: What is the total sales amount?
# A:
#
# Q: What is the average salary per department?
# A:

# %% [markdown]
# # Part4

# %% [markdown]
# # Task8

# %%
from langchain_core.messages import HumanMessage

ambiguous_query = HumanMessage(
    content="Show me the best results"
)

response = llm.invoke([ambiguous_query])
print(response.content)
# Out:
# However, I need a bit more information about what you're looking for the "best results" in. Are you looking for:
#
# 1. Search results for a specific topic?
# 2. Recommendations for a product or service?
# 3. Top tips or advice on a particular subject?
# 4. Something else entirely?
#
# Please provide more context or details, and I'll do my best to provide you with the information you're looking for.

# %% [markdown]
# # Observations & Insights :
# 1. Why SQL agents are better than manual SQL generation
#
# Automatically infer schema
#
# Reduce syntax errors
#
# Safer query execution
#
# 2. SQL Agent vs RAG
#
# SQL Agent → structured data
#
# RAG → unstructured text
#
# 3. Risks of unrestricted SQL access
#
# Data leakage
#
# Table deletion
#
# Unauthorized access
