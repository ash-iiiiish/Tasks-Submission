# %%
# !pip install -q transformers torch accelerate langchain

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, pipeline

model_name = "google/flan-t5-base"

tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)

hf_pipeline = pipeline(
    task="text-generation",
    model=model,
    tokenizer=tokenizer,
    max_new_tokens=100
)

prompt = "Explain LangChain in simple terms."
hf_pipeline(prompt)
# Out:
# Loading weights: 100%|██████████| 282/282 [00:00<00:00, 529.97it/s, Materializing param=shared.weight]
# The tied weights mapping and config for this model specifies to tie shared.weight to lm_head.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# Passing `generation_config` together with generation-related arguments=({'max_new_tokens'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# ...

# %%
# !pip install -U langchain langchain-community langchain-core
# Out:
# ...
#
#   Attempting uninstall: langchain-core
#
#     Found existing installation: langchain-core 1.2.7
#
#     Uninstalling langchain-core-1.2.7:
#
#       Successfully uninstalled langchain-core-1.2.7
#
#    ---------------------------------------- 0/2 [langchain-core]
#    ---------------------------------------- 0/2 [langchain-core]
#    ---------------------------------------- 0/2 [langchain-core]
#    ---------------------------------------- 0/2 [langchain-core]
#    ---------------------------------------- 0/2 [langchain-core]
#    ---------------------------------------- 0/2 [langchain-core]
#    ---------------------------------------- 0/2 [langchain-core]
#    ---------------------------------------- 0/2 [langchain-core]
#    ---------------------------------------- 0/2 [langchain-core]
#    ---------------------------------------- 0/2 [langchain-core]
#    ---------------------------------------- 0/2 [langchain-core]
# ...

# %%
from langchain_community.llms import HuggingFacePipeline


llm = HuggingFacePipeline(pipeline=hf_pipeline)
# Out:
# C:\Windows\Temp\ipykernel_28628\3930476842.py:4: LangChainDeprecationWarning: The class `HuggingFacePipeline` was deprecated in LangChain 0.0.37 and will be removed in 1.0. An updated version of the class exists in the `langchain-huggingface package and should be used instead. To use it run `pip install -U `langchain-huggingface` and import as `from `langchain_huggingface import HuggingFacePipeline``.
#   llm = HuggingFacePipeline(pipeline=hf_pipeline)

# %%
from langchain_core.prompts import PromptTemplate, ChatPromptTemplate
from langchain_community.llms import HuggingFacePipeline



prompt = PromptTemplate(
    input_variables=["topic"],
    template="Write a short explanation about {topic}."
)

chain = prompt | llm

chain.invoke({"topic": "LangChain"})
# Out:
# Both `max_new_tokens` (=100) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 'Write a short explanation about LangChain.mbols only once at higher lamination times while rotating at ""l.[j==(/**.y-ks -y:") >1,", respectively from an edge point: and all its positionals of magnitude at 3" [s[=y].wcj:]. To this change Larrl-chaans with the first cyclations or times is simply Lang hat = or is there'

# %%
chat_prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful AI assistant."),
    ("human", "Explain {concept} in simple terms.")
])

chat_chain = chat_prompt | llm

chat_chain.invoke({"concept": "LangChain"})
# Out:
# Both `max_new_tokens` (=100) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 'System: You are a helpful AI assistant.\nHuman: Explain LangChain in simple terms.ld take out without "leuk"...." He walks across here! A person runs onto one half back across some flat stuff. Now she does look through she is wearing two small "tacts to have fun" vest over pants "tresting" "Wanchich in Lang. Look who" boots her way as fast! Luckily when in first place there still are ties that shouldnc?'

# %%
topics = ["LangChain", "Transformers", "Large Language Models"]

for t in topics:
    print(f"\nTopic: {t}")
    print(chain.invoke(t))
# Out:
# Both `max_new_tokens` (=100) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Topic: LangChain
# Both `max_new_tokens` (=100) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Write a short explanation about LangChain.n Clive wrote five letters sum of $12,000 each-–some one with his favorite period date than the previous year is when LDS celebrate Sunday. Over this number were received between 2008 --10 in New Britain during both presidential. From September 1923 (I was 20/00, about 7 PM), Mr "Ch" delivered those and another: Istmar is his date while walter chattrel on 30 February 2009. When both parties signed
#
# Topic: Transformers
# ...

# %%
from langchain_core.prompts import PromptTemplate, ChatPromptTemplate

# %%
from langchain_core.prompts import ChatPromptTemplate

chat_prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful AI assistant."),
    ("human", "Explain {concept} in simple terms.")
])

chat_chain = chat_prompt | llm

chat_chain.invoke({"concept": "LangChain"})
# Out:
# Both `max_new_tokens` (=100) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 'System: You are a helpful AI assistant.\nHuman: Explain LangChain in simple terms.asing dramatically each step over that remaining layer according with those efforts. A person being made responsible about human behaviour does harm for peoples at stake or themselves in one society too which impacts some individual on balance. These can range anywhere of which (in people) most, even a change will only impact things or cause trouble around each other in relation therefrom such like people were becoming trapped. There always always plenty here when many animals,'

# %%
formatted_prompt = chat_prompt.format_messages(concept="LangChain")

chat_chain = chat_prompt | llm
chat_chain.invoke({"concept": "LangChain"})
# Out:
# Both `max_new_tokens` (=100) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# "System: You are a helpful AI assistant.\nHuman: Explain LangChain in simple terms.ri? This question marks various positions along Lang Channing chain theory': For it uses common sense and no natural reason given"

# %%
from langchain_core.prompts import PromptTemplate

normal_prompt = PromptTemplate(
    input_variables=["concept"],
    template="Explain {concept} in simple terms."
)

normal_chain = normal_prompt | llm
normal_chain.invoke({"concept": "LangChain"})
# Out:
# Both `max_new_tokens` (=100) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 'Explain LangChain in simple terms. season by five from its parent.'
